# %%
files = dbutils.fs.ls('/databricks-datasets/Rdatasets/data-001/csv/ggplot2/')

for file in files:
    file_path = f'/databricks-datasets/Rdatasets/data-001/csv/ggplot2/{file.name}'
    df = (
    spark.read.option("header",True).csv(file_path)
    )
    row_count = df.count()
    print(f"{file.name.split(".")[0]} rows are {row_count}")

# %%
dbutils.widgets.text("file_name","diamonds")

# %%
file_name = dbutils.widgets.get("file_name")

# %%
file_path = f'/databricks-datasets/Rdatasets/data-001/csv/ggplot2/{file_name}.csv'
file_path

# %%
df = (
    spark.read.option("header",True).csv(file_path)
)

row_count = df.count()
print(f"{file_name} rows are {row_count}")
dbutils.notebook.exit(row_count)
