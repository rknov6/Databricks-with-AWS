# %%
dbutils.help()

# %%
# %fs
ls /databricks-datasets

# %%
files = dbutils.fs.ls('/databricks-datasets/')
for file in files:
    print(f"{file.name} and {file.size}")

# %%
dbutils.fs.mkdirs('/Workspace/Shared/config/')

# %%
dbutils.fs.rm('/Workspace/Shared/config/',True)

# %%
config_content = """
Hello how are you
"""

# %%
dbutils.fs.put("/Workspace/Shared/config/application.cfg",config_content,True)

# %%
dbutils.fs.rm("/Workspace/Shared/config",True)

# %%
result = dbutils.notebook.run("02.Row_Count",60,{"file_name":"msleep"})
print(result)
